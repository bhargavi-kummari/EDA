# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import zipfile
zip_file_path = "/content/archive.zip"
csv_file_name = "amsterdam_weekdays.csv"
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
   amsterdam_weekdays = pd.read_csv(zip_ref.open(csv_file_name))


csv_file_name = "athens_weekdays.csv"
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
  athens_weekdays= pd.read_csv(zip_ref.open(csv_file_name))

csv_file_name = "barcelona_weekdays.csv"
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
  barcelona_weekdays= pd.read_csv(zip_ref.open(csv_file_name))

csv_file_name = "berlin_weekdays.csv"
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
  berlin_weekdays= pd.read_csv(zip_ref.open(csv_file_name))


csv_file_name = "budapest_weekdays.csv"
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
  budapest_weekdays= pd.read_csv(zip_ref.open(csv_file_name))

csv_file_name = "lisbon_weekdays.csv"
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
  lisbon_weekdays= pd.read_csv(zip_ref.open(csv_file_name))

csv_file_name = "london_weekdays.csv"
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
  london_weekdays= pd.read_csv(zip_ref.open(csv_file_name))

csv_file_name = "paris_weekdays.csv"
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
  paris_weekdays= pd.read_csv(zip_ref.open(csv_file_name))

csv_file_name = "rome_weekdays.csv"
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
  rome_weekdays= pd.read_csv(zip_ref.open(csv_file_name))


csv_file_name = "vienna_weekdays.csv"
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
  vienna_weekdays= pd.read_csv(zip_ref.open(csv_file_name))

# %%
csv_file_name = "amsterdam_weekends.csv"
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
   amsterdam_weekends = pd.read_csv(zip_ref.open(csv_file_name))


csv_file_name = "athens_weekends.csv"
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
  athens_weekends= pd.read_csv(zip_ref.open(csv_file_name))

csv_file_name = "barcelona_weekends.csv"
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
  barcelona_weekends= pd.read_csv(zip_ref.open(csv_file_name))

csv_file_name = "berlin_weekends.csv"
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
  berlin_weekends= pd.read_csv(zip_ref.open(csv_file_name))


csv_file_name = "budapest_weekends.csv"
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
  budapest_weekends= pd.read_csv(zip_ref.open(csv_file_name))

csv_file_name = "lisbon_weekends.csv"
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
  lisbon_weekends= pd.read_csv(zip_ref.open(csv_file_name))

csv_file_name = "london_weekends.csv"
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
  london_weekends= pd.read_csv(zip_ref.open(csv_file_name))

csv_file_name = "paris_weekends.csv"
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
  paris_weekends= pd.read_csv(zip_ref.open(csv_file_name))

csv_file_name = "rome_weekends.csv"
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
  rome_weekends= pd.read_csv(zip_ref.open(csv_file_name))


csv_file_name = "vienna_weekends.csv"
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
  vienna_weekends= pd.read_csv(zip_ref.open(csv_file_name))

# %%
amsterdam_weekdays["city"]="Amsterdam"
athens_weekdays["city"]="Athens"
barcelona_weekdays["city"]="Barcelona"
berlin_weekdays["city"]="Berlin"
budapest_weekdays["city"]="Budapest"
lisbon_weekdays["city"]="lisbon"
london_weekdays["city"]="London"
paris_weekdays["city"]="Paris"
rome_weekdays["city"]="Rome"
vienna_weekdays["city"]="vienna"
amsterdam_weekends["city"]="Amsterdam"
athens_weekends["city"]="athens"
barcelona_weekends["city"]="barcelona"
berlin_weekends["city"]="berlin"
budapest_weekends["city"]="budapest"
lisbon_weekends["city"]="lisbon"
london_weekends["city"]="London"
paris_weekends["city"]="Paris"
rome_weekends["city"]="Rome"
vienna_weekends["city"]="vienna"

# %%
# Concatenate files into two master datasets: one for weekdays and one for weekends.
weekdays=pd.concat([amsterdam_weekdays,athens_weekdays,barcelona_weekdays,berlin_weekdays,budapest_weekdays,lisbon_weekdays,london_weekdays,paris_weekdays,rome_weekdays,vienna_weekdays],ignore_index=True)
weekdays.head(5)
# Out:
#    Unnamed: 0     realSum     room_type  room_shared  room_private  \
# 0           0  194.033698  Private room        False          True
# 1           1  344.245776  Private room        False          True
# 2           2  264.101422  Private room        False          True
# 3           3  433.529398  Private room        False          True
# 4           4  485.552926  Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              2.0              False      1    0                10.0  ...
# 1              4.0              False      0    0                 8.0  ...
# 2              2.0              False      0    1                 9.0  ...
# 3              4.0              False      0    1                 9.0  ...
# 4              2.0               True      0    0                10.0  ...
#
#    bedrooms      dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# ...

# %%
weekends=pd.concat([amsterdam_weekends,athens_weekends,barcelona_weekends,berlin_weekends,budapest_weekends,lisbon_weekends,london_weekends,paris_weekends,rome_weekends,vienna_weekends],ignore_index=True)
weekends.head(5)
# Out:
#    Unnamed: 0      realSum        room_type  room_shared  room_private  \
# 0           0   319.640053     Private room        False          True
# 1           1   347.995219     Private room        False          True
# 2           2   482.975183     Private room        False          True
# 3           3   485.552926     Private room        False          True
# 4           4  2771.541724  Entire home/apt        False         False
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              2.0              False      0    1                 9.0  ...
# 1              2.0              False      0    1                 9.0  ...
# 2              4.0              False      0    1                 9.0  ...
# 3              2.0               True      0    0                10.0  ...
# 4              4.0               True      0    0                10.0  ...
#
#    bedrooms      dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# ...

# %%
# Combine the datasets into a single unified dataset with an additional column indicating "day_type" as either 'weekday' or 'weekend'.
weekends["data_type"]="weekend"
weekdays["data_type"]="weekdays"

# %%
combined_data=pd.concat([weekdays,weekends],ignore_index=True)
combined_data.head(5)
# Out:
#    Unnamed: 0     realSum     room_type  room_shared  room_private  \
# 0           0  194.033698  Private room        False          True
# 1           1  344.245776  Private room        False          True
# 2           2  264.101422  Private room        False          True
# 3           3  433.529398  Private room        False          True
# 4           4  485.552926  Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              2.0              False      1    0                10.0  ...
# 1              4.0              False      0    0                 8.0  ...
# 2              2.0              False      0    1                 9.0  ...
# 3              4.0              False      0    1                 9.0  ...
# 4              2.0               True      0    0                10.0  ...
#
#        dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# ...

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51707 entries, 0 to 51706
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  51707 non-null  int64
#  1   realSum                     51707 non-null  float64
#  2   room_type                   51707 non-null  object
#  3   room_shared                 51707 non-null  bool
#  4   room_private                51707 non-null  bool
#  5   person_capacity             51707 non-null  float64
#  6   host_is_superhost           51707 non-null  bool
#  7   multi                       51707 non-null  int64
#  8   biz                         51707 non-null  int64
#  9   cleanliness_rating          51707 non-null  float64
#  10  guest_satisfaction_overall  51707 non-null  float64
#  11  bedrooms                    51707 non-null  int64
#  12  dist                        51707 non-null  float64
# ...

# %%
combined_data.drop(["Unnamed: 0","attr_index","attr_index_norm","rest_index","rest_index_norm"],inplace=True,axis=1)
combined_data.head(4)
# Out:
#       realSum     room_type  room_shared  room_private  person_capacity  \
# 0  194.033698  Private room        False          True              2.0
# 1  344.245776  Private room        False          True              4.0
# 2  264.101422  Private room        False          True              2.0
# 3  433.529398  Private room        False          True              4.0
#
#    host_is_superhost  multi  biz  cleanliness_rating  \
# 0              False      1    0                10.0
# 1              False      0    0                 8.0
# 2              False      0    1                 9.0
# 3              False      0    1                 9.0
#
#    guest_satisfaction_overall  bedrooms      dist  metro_dist      lng  \
# 0                        93.0         1  5.022964    2.539380  4.90569
# 1                        85.0         1  0.488389    0.239404  4.90005
# 2                        87.0         1  5.748312    3.651621  4.97512
# ...

# %%
#Data Cleaning:
#Check for missing values and impute or remove them appropriately.
combined_data.isnull().sum()
# Out:
# realSum                       0
# room_type                     0
# room_shared                   0
# room_private                  0
# person_capacity               0
# host_is_superhost             0
# multi                         0
# biz                           0
# cleanliness_rating            0
# guest_satisfaction_overall    0
# bedrooms                      0
# dist                          0
# metro_dist                    0
# lng                           0
# lat                           0
# city                          0
# data_type                     0
# dtype: int64

# %%
# Handle duplicates if present.
combined_data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
#  Ensure correct data types for columns (e.g., numerical columns, categorical
#  columns).
# > The categorical columns are
# 1. room_type: the type of the accommodation
# 2. room_shared: dummy variable for shared rooms
# 3. room_private: dummy variable for private rooms
# 4. host_is_superhost: dummy variable for superhost status and
#  data_type
#
# The numerical columns are
# 1. realSum: the full price of accommodation for two people and two nights in EUR
# 2. person_capacity: the maximum number of guests
# 3. multi: dummy variable if the listing belongs to hosts with 2-4 offers
# 4. biz: dummy variable if the listing belongs to hosts with more than 4 offers
# 5. cleanliness_rating: cleanliness rating
# 6. guest_satisfaction_overall: overall rating of the listing
# 7.  bedrooms: number of bedrooms (0 for studios)
# 8.  dist: distance from city centre in km
# 9.  metro_dist: distance from nearest metro station in km
# 10. attr_index: attraction index of the listing location
# 11. attr_index_norm: normalised attraction index (0-100)
# 12. rest_index: restaurant index of the listing location
# 13. rest_index_norm: normalised restaurant index (0-100)
# 14. lng: longitude of the listing location
# 15. lat: latitude of the listing location

# %%
#Address any outliers in key features such as realSum (price) and guest_satisfaction_overall.
fig, axes = plt.subplots(3, 2,figsize=(10,10))

sns.boxplot(data=combined_data, x='realSum', ax=axes[0,0])
sns.boxplot(data=combined_data, x='cleanliness_rating', ax=axes[0,1])
sns.boxplot(data=combined_data, x='guest_satisfaction_overall', ax=axes[1,0])
sns.boxplot(data=combined_data, x='dist', ax=axes[1,1])
sns.boxplot(data=combined_data, x='metro_dist', ax=axes[2,1])
plt.show()

# %%
#3. Exploratory Analysis-Univariate Analysis
#Price Distribution: Plot histograms and boxplots of realSum to understand price distributions for weekdays and weekends separately.
sns.histplot(data=combined_data, hue='data_type', x='realSum',kde=True,bins=20)
# Out:
# <Axes: xlabel='realSum', ylabel='Count'>

# %%
sns.barplot(data=combined_data, x='data_type', y='realSum')
# Out:
# <Axes: xlabel='data_type', ylabel='realSum'>

# %%
# Room Types: Visualize counts of different room_type categories (e.g., shared, private, entire home).
fig, axes = plt.subplots(3, 2,figsize=(10,10))

sns.countplot(data=combined_data, x='room_type', ax=axes[0,0])
sns.countplot(data=combined_data, x='room_shared', ax=axes[0,1])
sns.countplot(data=combined_data, x='room_private', ax=axes[1,0])
sns.countplot(data=combined_data, x='person_capacity', ax=axes[1,1])
sns.countplot(data=combined_data, x='cleanliness_rating', ax=axes[2,0])
sns.countplot(data=combined_data, x='bedrooms', ax=axes[2,1])
plt.show()

# %%
# Guest Satisfaction: Plot distribution of guest_satisfaction_overall ratings.
sns.histplot(data=combined_data, x='guest_satisfaction_overall',kde=True)
# Out:
# <Axes: xlabel='guest_satisfaction_overall', ylabel='Count'>

# %%
# Bivariate Analysis
#Price vs. Room Type: Compare average prices for different room_type categories between weekdays and weekends using bar plots.
sns.barplot(data=combined_data, x='room_type', y='realSum', hue='data_type')
# Out:
# <Axes: xlabel='room_type', ylabel='realSum'>

# %%
#Superhost Status: Analyze how host_is_superhost impacts average prices and guest satisfaction ratings using boxplots or violin plots.
sns.boxplot(data=combined_data, x='host_is_superhost', y='realSum')
# Out:
# <Axes: xlabel='host_is_superhost', ylabel='realSum'>

# %%
sns.boxplot(data=combined_data, x='host_is_superhost', y='guest_satisfaction_overall')
# Out:
# <Axes: xlabel='host_is_superhost', ylabel='guest_satisfaction_overall'>

# %%
# Distance Impact: Plot realSum against dist and metro_dist to understand how distance from city center and metro stations affects pricing.
sns.lineplot(data=combined_data, x='dist', y='realSum')
# Out:
# <Axes: xlabel='dist', ylabel='realSum'>

# %%
sns.lineplot(data=combined_data, x='metro_dist', y='realSum')
# Out:
# <Axes: xlabel='metro_dist', ylabel='realSum'>

# %%
#Multivariate Analysis
# Heatmaps: Generate correlation heatmaps to explore relationships among realSum, cleanliness_rating, guest_satisfaction_overall, person_capacity, and other features.
correlation=combined_data[['realSum','cleanliness_rating','guest_satisfaction_overall','person_capacity','bedrooms','dist','metro_dist','lng','lat']].corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm',fmt="0.2f")
# Out:
# <Axes: >

# %%
#Feature Interactions: Explore how combinations of features (e.g., multi and biz) influence price and satisfaction.
sns.barplot(data=combined_data, x='multi', y='realSum', hue='biz')
# Out:
# <Axes: xlabel='multi', ylabel='realSum'>

# %%
sns.barplot(data=combined_data, x='multi', y='guest_satisfaction_overall', hue='biz')
# Out:
# <Axes: xlabel='multi', ylabel='guest_satisfaction_overall'>

# %%
#City-Specific Analysis
# City Comparison: Compare key metrics (average price, room types, guest satisfaction) across different cities in Europe.
plt.fig=plt.figure(figsize=(10,3))
plt.title("average price according to the different cities")
sns.barplot(data=combined_data, x='city', y='realSum')
plt.show()

# %%
plt.fig=plt.figure(figsize=(10,3))
plt.title("room type according to the different cities")
sns.countplot(data=combined_data, x='city', hue='room_type')
plt.show()

# %%
plt.fig=plt.figure(figsize=(10,3))
plt.title("guest satisfaction according to the different cities")
sns.barplot(data=combined_data, x='city', y='guest_satisfaction_overall')
plt.show()

# %%
#Weekday vs. Weekend Analysis
#Price Fluctuation: Analyze the difference in average and median prices between weekdays and weekends for each city.
combined_data.groupby(["city","data_type"])["realSum"].mean()
# Out:
# city       data_type
# Amsterdam  weekdays     545.020526
#            weekend      604.828018
# Athens     weekdays     155.866982
# Barcelona  weekdays     288.391667
# Berlin     weekdays     240.220422
# Budapest   weekdays     168.429367
# London     weekdays     360.230348
#            weekend      364.389747
# Paris      weekdays     398.786678
#            weekend      387.028589
# Rome       weekdays     201.618053
#            weekend      209.130063
# athens     weekend      147.580456
# barcelona  weekend      300.277940
# berlin     weekend      249.252516
# budapest   weekend      185.120628
# lisbon     weekdays     236.345459
#            weekend      240.044051
# vienna     weekdays     240.384834
#            weekend      242.739524
# Name: realSum, dtype: float64

# %%
combined_data.groupby(["city","data_type"])["realSum"].median()
# Out:
# city       data_type
# Amsterdam  weekdays     430.248635
#            weekend      491.645771
# Athens     weekdays     127.715417
# Barcelona  weekdays     208.532129
# Berlin     weekdays     187.786295
# Budapest   weekdays     147.459698
# London     weekdays     256.355982
#            weekend      268.115431
# Paris      weekdays     318.529220
#            weekend      316.199087
# Rome       weekdays     179.786314
#            weekend      184.462161
# athens     weekend      127.715417
# barcelona  weekend      204.691973
# berlin     weekend      192.460503
# budapest   weekend      160.031959
# lisbon     weekdays     223.030019
#            weekend      227.720450
# vienna     weekdays     204.520487
#            weekend      212.000093
# Name: realSum, dtype: float64

# %%
# Room Availability: Explore how room capacity (person_capacity) changes across day types
sns.countplot(data=combined_data, x='person_capacity', hue='data_type')
# Out:
# <Axes: xlabel='person_capacity', ylabel='count'>

# %%
#Satisfaction Variability: Investigate whether guest satisfaction scores differ between weekday and weekend stays.
sns.barplot(data=combined_data, x='data_type', y='guest_satisfaction_overall')
# Out:
# <Axes: xlabel='data_type', ylabel='guest_satisfaction_overall'>

# %%
# Insights and Recommendations
#For Hosts: Provide recommendations on pricing strategies based on city-specific data and weekday/weekend patterns.
#For Guests: Suggest best times and cities for lower prices and higher guest satisfaction

# %% [markdown]
# The difference in amsterdam is more when compared between the weekends and weekdays. We can increase the price in the other location as well as
# the most people are willing to accomodate on the weekends.
#
#
# For guests:
# As we can see from the above analysis the prices are less in evenry location except amsterdan. The over all guest satifaction is also good in every location. You can also see that you have most of the location are near to the city center or the metro station.

# %%
# Summary of Key Findings: Summarize the main trends observed in price variations, room types, guest satisfaction, and city differences.
 #Data-Driven Recommendations: Provide actionable strategies for Airbnb hosts and management to maximize occupancy and satisfaction.

# %% [markdown]
# As we can see that for the entire room or apartment it costed more when compared to the room shared and room private.The over all guest rating is good in every location.
#
#
# As most of the people need the entire room or apartment, on weekends with the person capcity of 2 or either 3 and single bedroom which are near to the metro station and city center are we vary the price according to this.

# %%
#seperating input and target variable
x=combined_data.drop("realSum",axis=1)
y=combined_data["realSum"]

# %%
#split into train and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)
print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)
# Out:
# (38780, 16) (38780,)
# (12927, 16) (12927,)

# %%
#seperating num and cat columns
x_train_cat=x_train.select_dtypes(include=["object","bool"])
x_train_num=x_train.select_dtypes(include=["int64","float64"])

# %%
#rescaling numeric features
from sklearn.preprocessing import StandardScaler
Standard_scalar=StandardScaler()
#data converted to a nd numpy array
x_train_num_transformed=pd.DataFrame(Standard_scalar.fit_transform(x_train_num),columns=Standard_scalar.get_feature_names_out(),index=x_train_num.index)
x_train_num_transformed.head()
# Out:
#        person_capacity     multi       biz  cleanliness_rating  \
# 30462         0.650568 -0.638853  1.358687            0.629274
# 45862        -0.893436  1.565304 -0.736005            0.629274
# 43615        -0.893436  1.565304 -0.736005            0.629274
# 21014        -0.893436 -0.638853 -0.736005            0.629274
# 38923        -0.893436 -0.638853 -0.736005            0.629274
#
#        guest_satisfaction_overall  bedrooms      dist  metro_dist       lng  \
# 30462                    0.044074 -0.252366 -0.971802   -0.346315  0.612884
# 45862                    0.814372 -0.252366 -0.214692   -0.183879  0.516882
# 43615                    0.814372 -0.252366 -0.115014   -0.393210 -0.518759
# 21014                   -0.065969 -0.252366  0.645032   -0.301992  0.522474
# 38923                    0.814372 -0.252366  2.552473    5.335694 -0.761527
#
#             lat
# 30462  1.300839
# 45862 -0.723817
# 43615  0.608338
# 21014 -0.726248
# 38923  1.095948

# %%
#one hot encoding the categorical columns
from sklearn.preprocessing import OneHotEncoder
onehot_encoder=OneHotEncoder(sparse_output=False,handle_unknown="ignore")      #handle_unknown=ignore only takes the values which are in train data the test data values are ignored
x_train_cat_transformed=pd.DataFrame(onehot_encoder.fit_transform(x_train_cat),
                                     columns=onehot_encoder.get_feature_names_out(),index=x_train_cat.index)
print("shape of the data before transformation=",x_train_cat.shape)
print("shape of the data after transformation=",x_train_cat_transformed.shape)
x_train_cat_transformed.head()
# Out:
# shape of the data before transformation= (38780, 6)
# shape of the data after transformation= (38780, 25)
#        room_type_Entire home/apt  room_type_Private room  \
# 30462                        0.0                     0.0
# 45862                        0.0                     1.0
# 43615                        0.0                     1.0
# 21014                        0.0                     1.0
# 38923                        0.0                     1.0
#
#        room_type_Shared room  room_shared_False  room_shared_True  \
# 30462                    1.0                0.0               1.0
# 45862                    0.0                1.0               0.0
# 43615                    0.0                1.0               0.0
# 21014                    0.0                1.0               0.0
# 38923                    0.0                1.0               0.0
#
#        room_private_False  room_private_True  host_is_superhost_False  \
# ...

# %%
x_train_transformed=pd.concat([x_train_num_transformed,x_train_cat_transformed],axis=1)
x_train_transformed.head()
# Out:
#        person_capacity     multi       biz  cleanliness_rating  \
# 30462         0.650568 -0.638853  1.358687            0.629274
# 45862        -0.893436  1.565304 -0.736005            0.629274
# 43615        -0.893436  1.565304 -0.736005            0.629274
# 21014        -0.893436 -0.638853 -0.736005            0.629274
# 38923        -0.893436 -0.638853 -0.736005            0.629274
#
#        guest_satisfaction_overall  bedrooms      dist  metro_dist       lng  \
# 30462                    0.044074 -0.252366 -0.971802   -0.346315  0.612884
# 45862                    0.814372 -0.252366 -0.214692   -0.183879  0.516882
# 43615                    0.814372 -0.252366 -0.115014   -0.393210 -0.518759
# 21014                   -0.065969 -0.252366  0.645032   -0.301992  0.522474
# 38923                    0.814372 -0.252366  2.552473    5.335694 -0.761527
#
#             lat  ...  city_Paris  city_Rome  city_athens  city_barcelona  \
# ...

# %%
#x_test
x_test_cat=x_test.select_dtypes(include=["object","bool"])
x_test_num=x_test.select_dtypes(include=["int64","float64"])

# %%
x_test_num_transformed=pd.DataFrame(Standard_scalar.fit_transform(x_test_num),columns=Standard_scalar.get_feature_names_out(),index=x_test_num.index)
x_test_num_transformed.head()
# Out:
#        person_capacity     multi       biz  cleanliness_rating  \
# 11919         1.395454 -0.648257  1.372663           -0.436413
# 44311        -0.898129 -0.648257 -0.728511           -1.540860
# 11843        -0.898129 -0.648257 -0.728511           -0.436413
# 28278         0.630926 -0.648257 -0.728511            0.668034
# 9939         -0.898129  1.542598 -0.728511           -1.540860
#
#        guest_satisfaction_overall  bedrooms      dist  metro_dist       lng  \
# 11919                   -1.494968  1.321812  0.122135   -0.723138 -0.778778
# 44311                   -1.024648 -0.255067  0.149914   -0.449685 -0.519688
# 11843                    0.033572 -0.255067  0.797747    1.421538 -0.778337
# 28278                    0.503892  1.321812 -0.325729   -0.352512  1.660411
# 9939                    -0.554328 -0.255067 -0.455456   -0.393625 -1.693493
#
#             lat
# 11919  1.123233
# 44311  0.609581
# 11843  1.115133
# 28278 -1.464669
# 9939  -1.318585

# %%
x_test_cat_transformed=pd.DataFrame(onehot_encoder.fit_transform(x_test_cat),
                                     columns=onehot_encoder.get_feature_names_out(),index=x_test_cat.index)
print("shape of the data before transformation=",x_test_cat.shape)
print("shape of the data after transformation=",x_test_cat_transformed.shape)
x_test_cat_transformed.head()
# Out:
# shape of the data before transformation= (12927, 6)
# shape of the data after transformation= (12927, 25)
#        room_type_Entire home/apt  room_type_Private room  \
# 11919                        1.0                     0.0
# 44311                        0.0                     1.0
# 11843                        0.0                     1.0
# 28278                        1.0                     0.0
# 9939                         0.0                     1.0
#
#        room_type_Shared room  room_shared_False  room_shared_True  \
# 11919                    0.0                1.0               0.0
# 44311                    0.0                1.0               0.0
# 11843                    0.0                1.0               0.0
# 28278                    0.0                1.0               0.0
# 9939                     0.0                1.0               0.0
#
#        room_private_False  room_private_True  host_is_superhost_False  \
# ...

# %%
x_test_transformed=pd.concat([x_test_num_transformed,x_test_cat_transformed],axis=1)
x_test_transformed.head()
# Out:
#        person_capacity     multi       biz  cleanliness_rating  \
# 11919         1.395454 -0.648257  1.372663           -0.436413
# 44311        -0.898129 -0.648257 -0.728511           -1.540860
# 11843        -0.898129 -0.648257 -0.728511           -0.436413
# 28278         0.630926 -0.648257 -0.728511            0.668034
# 9939         -0.898129  1.542598 -0.728511           -1.540860
#
#        guest_satisfaction_overall  bedrooms      dist  metro_dist       lng  \
# 11919                   -1.494968  1.321812  0.122135   -0.723138 -0.778778
# 44311                   -1.024648 -0.255067  0.149914   -0.449685 -0.519688
# 11843                    0.033572 -0.255067  0.797747    1.421538 -0.778337
# 28278                    0.503892  1.321812 -0.325729   -0.352512  1.660411
# 9939                    -0.554328 -0.255067 -0.455456   -0.393625 -1.693493
#
#             lat  ...  city_Paris  city_Rome  city_athens  city_barcelona  \
# ...

# %% [markdown]
# ###LinearRegression

# %%
from sklearn.linear_model import LinearRegression
import time

regressor=LinearRegression()

st=time.time()
regressor.fit(x_train_transformed,y_train)
et=time.time()
print("Total time taken to train the model ",st-et)
# Out:
# Total time taken to train the model  -0.05355548858642578

# %%
st=time.time()
y_test_pred=regressor.predict(x_test_transformed)
et=time.time()
print("Total time taken for prediction is ",st-et)
# Out:
# Total time taken for prediction is  -0.007302522659301758

# %%
from sklearn import metrics
print("mean_absolute_error ", metrics.mean_absolute_error(y_test,y_test_pred))
# Out:
# mean_absolute_error  107.08067534797584

# %% [markdown]
# ###KNeighbors

# %%
from sklearn.neighbors import KNeighborsRegressor

regressor=KNeighborsRegressor()

st=time.time()
regressor.fit(x_train_transformed,y_train)
et=time.time()
print("Total time taken to train the model ",st-et)
# Out:
# Total time taken to train the model  -0.025204896926879883

# %%
st=time.time()
y_test_pred=regressor.predict(x_test_transformed)
et=time.time()
print("Total time taken for prediction is ",st-et)
# Out:
# Total time taken for prediction is  -3.3748695850372314

# %%
from sklearn import metrics
print("model error ", metrics.mean_absolute_error(y_test,y_test_pred))
# Out:
# model error  87.17926669192852

# %% [markdown]
# ###DecisionTree

# %%
from sklearn.tree import DecisionTreeRegressor

regressor=DecisionTreeRegressor()

st=time.time()
regressor.fit(x_train_transformed,y_train)
et=time.time()
print("Total time taken to train the model ",st-et)
# Out:
# Total time taken to train the model  -0.6148324012756348

# %%
st=time.time()
y_test_pred=regressor.predict(x_test_transformed)
et=time.time()
print("Total time taken for prediction is ",st-et)
# Out:
# Total time taken for prediction is  -0.008960962295532227

# %%
from sklearn import metrics
print("model error ", metrics.mean_absolute_error(y_test,y_test_pred))
# Out:
# model error  136.40444125048677

# %% [markdown]
# ###DataFrame of Models

# %%
df1=pd.DataFrame({"Model":["LR_Regressor","KNn_Regressor","DT_Regressor"],
                     "mean_absolute_error":[107.080,87.179,136.404],
                     "TrainingTime":[0.053,0.025,0.614],
                     "PredictionTime":[0.007,3.374,0.008]})
df1
# Out:
#            Model  mean_absolute_error  TrainingTime  PredictionTime
# 0   LR_Regressor              107.080         0.053           0.007
# 1  KNn_Regressor               87.179         0.025           3.374
# 2   DT_Regressor              136.404         0.614           0.008

# %%
df1.to_csv("model_performance.csv",index=False)

# %%
df1
# Out:
#            Model  mean_absolute_error  TrainingTime  PredictionTime
# 0   LR_Regressor              107.080         0.053           0.007
# 1  KNn_Regressor               87.179         0.025           3.374
# 2   DT_Regressor              136.404         0.614           0.008

# %%
sns.barplot(data=df1,x="Model",y="mean_absolute_error")
# Out:
# <Axes: xlabel='Model', ylabel='mean_absolute_error'>

# %%
sns.barplot(data=df1,x="Model",y="TrainingTime")
# Out:
# <Axes: xlabel='Model', ylabel='TrainingTime'>

# %%
sns.barplot(data=df1,x="Model",y="PredictionTime")
# Out:
# <Axes: xlabel='Model', ylabel='PredictionTime'>
